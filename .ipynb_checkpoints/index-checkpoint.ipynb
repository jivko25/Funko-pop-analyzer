# %% [markdown]
# # Funko pop analyzer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# В този проект ще се опитаме първо да изчистим данните за фукно поп фигурки и данни за филми, след това ще опитаме да ги обединим като ще се опитаме да проверим няколко хипотези
# Идеи за хипотези:
# H1: Филми с по-висок рейтинг (IMDb/Rotten Tomatoes) имат повече Funko Pop продукти
# H2: Box office приходите са по-силен фактор за броя фигурки от рейтинга
# H3: Филми от franchise (Marvel, Star Wars и т.н.) имат непропорционално повече фигурки спрямо standalone филми
# H4: Определени жанрове (action, fantasy, animation) имат значително повече Funko Pop фигурки
# H5: Horror филмите имат по-малко фигурки, но по-висока „нишова концентрация“ (по-малко филми, но с много фигурки)
# H6: По-новите филми имат повече Funko Pop фигурки (заради растежа на бранда)
# H7: Има пик в производството на фигурки около годината на излизане на филма
# H8: Филми от определени студиа (Disney, Warner Bros) имат повече фигурки
# H9: Collaboration ефект – когато има crossover (напр. Marvel), броят на фигурките расте експоненциално

# %%
df = pd.read_csv('funko.csv')

# %%
df
# Out:
#                 uid                                              title  \
# 0     7051374362813       "It's Crunch Time " Kids Tee - General Mills
# 1     7231381405885       "This is the Way" Kids Tee - The Mandalorian
# 2     7231381536957  "This is the Way" Neon Blast Kids Tee - The Ma...
# 3     7051374395581     "Time for a Midnight Bite" Tee - General Mills
# 4     7231381668029  "Where He Goes, I Go" Grogu Kids Tee - The Man...
# ...             ...                                                ...
# 1477  6958000734397                   Zombie Hunter Spidey - What If…?
# 1478  6958000963773                        Zombie Iron Man - What If…?
# 1479  7232416514237                                              Zorro
# 1480  6192471605437                  Zuko - Avatar: The Last Airbender
# 1481  7222808182973                                   Zurg - Lightyear
#
#      product_type  price       interest                        license  \
# 0         Apparel    7.0   ['Ad Icons']              ['General Mills']
# 1         Apparel   10.0  ['Star Wars']                  ['Star Wars']
# 2         Apparel   10.0  ['Star Wars']                  ['Star Wars']
# 3         Apparel   14.0   ['Ad Icons']              ['General Mills']
# 4         Apparel   10.0  ['Star Wars']                  ['Star Wars']
# ...           ...    ...            ...                            ...
# 1477         Pop!   12.0     ['Marvel']      ['Spider-Man', 'What If']
# 1478         Pop!   12.0     ['Marvel']        ['Iron Man', 'What If']
# 1479         Pop!   12.0   ['Classics']                      ['Zorro']
# 1480         Pop!   12.0      ['Anime']  ['Avatar The Last Airbender']
# 1481         Pop!   12.0      ['Pixar']                  ['Lightyear']
#
#                                                    tags             vendor  \
# 0     ['Apparel', 'Cereal Day', 'Kids Tee', 'Markdow...  Funko Pop Up Shop
# 1     ['Apparel', 'Kids Tee', 'May the 4th', 'May th...         Funko Shop
# 2     ['Apparel', 'May the 4th', 'May the 4th Be Wit...         Funko Shop
# 3     ['Apparel', 'Cereal Day', 'Markdown Item', 'Sa...  Funko Pop Up Shop
# 4     ['Apparel', 'May the 4th', 'May the 4th Be Wit...         Funko Shop
# ...                                                 ...                ...
# 1477  ['Disney Plus', 'FFCBDAY', 'Gift Box', 'Gift G...         Funko Shop
# 1478  ['Disney Plus', 'FFCBDAY', 'Gift Box', 'Gift G...         Funko Shop
# 1479           ['FFCBDAY', 'Gift Box', 'NOTIFY', 'PPP']         Funko Shop
# 1480  ['Chase', 'FEB032022', 'FFCBDAY', 'Gift Box', ...         Funko Shop
# 1481           ['FFCBDAY', 'Gift Box', 'NOTIFY', 'PPP']         Funko Shop
#
#      form_factor                              feature  \
# 0             []                                   []
# 1             []                                   []
# 2             []                                   []
# 3             []                                   []
# 4             []                                   []
# ...          ...                                  ...
# 1477          []                    ['Back In Stock']
# 1478          []                                   []
# 1479          []                      ['Coming Soon']
# 1480          []  ['Best Sellers', 'Chance of Chase']
# 1481          []                      ['Coming Soon']
#
#                                                 related  \
# 0     ['7051374788797', '7051374854333', '7051374723...
# 1     ['7254814130365', '7254814064829', '4491928240...
# 2     ['7254814130365', '7254814064829', '4491928240...
# 3     ['7051374788797', '7051374854333', '7051374723...
# 4     ['7254814130365', '7254814064829', '4491928240...
# ...                                                 ...
# 1477  ['6218636001469', '7078124683453', '7193953960...
# 1478  ['6958000734397', '7078124683453', '6924450332...
# 1479  ['6161453613245', '7193953599677', '7239037386...
# 1480  ['6192469999805', '6192471867581', '7087723282...
# 1481  ['7151004811453', '6868728348861', '7239037878...
#
#                                             description  \
# 0     <p>"It's Crunch Time" with the Count Chocula P...
# 1     <p>Celebrate May the Fourth in stellar style w...
# 2     <p>Celebrate May the Fourth in stellar style w...
# 3     <p>Like the Pop! Tee says, it's "Time for a Mi...
# 4     <p>Celebrate May the Fourth in stellar style w...
# ...                                                 ...
# 1477  In the endless possibilities, venture to wonde...
# 1478  In the endless possibilities, venture to wonde...
# 1479  Celebrate the 65th Anniversary of <i>Zorro</i>...
# 1480  <p>"I must capture the Avatar." Zuko, prince t...
# 1481  Explore infinite possibilities with our Pop! Z...
#
#                                       gid                 created_at  \
# 0     gid://shopify/Product/7051374362813  2021-10-29T00:02:52-00:00
# 1     gid://shopify/Product/7231381405885  2022-05-03T20:57:34-00:00
# 2     gid://shopify/Product/7231381536957  2022-05-03T20:57:40-00:00
# 3     gid://shopify/Product/7051374395581  2021-10-29T00:02:57-00:00
# 4     gid://shopify/Product/7231381668029  2022-05-03T20:57:45-00:00
# ...                                   ...                        ...
# 1477  gid://shopify/Product/6958000734397  2021-09-09T23:43:24-00:00
# 1478  gid://shopify/Product/6958000963773  2021-09-09T23:43:37-00:00
# 1479  gid://shopify/Product/7232416514237  2022-05-04T23:54:25-00:00
# 1480  gid://shopify/Product/6192471605437  2021-01-28T21:20:06-00:00
# 1481  gid://shopify/Product/7222808182973  2022-04-20T21:55:00-00:00
#
#                    published_at                 updated_at  \
# 0     2021-10-29T16:30:00-00:00  2022-05-23T16:50:36-00:00
# 1     2022-05-04T15:30:00-00:00  2022-05-27T13:25:49-00:00
# 2     2022-05-04T15:30:01-00:00  2022-05-29T18:15:32-00:00
# 3     2021-10-29T16:30:01-00:00  2022-05-26T04:04:45-00:00
# 4     2022-05-04T15:30:02-00:00  2022-05-30T02:40:26-00:00
# ...                         ...                        ...
# 1477  2022-05-26T16:41:07-00:00  2022-05-31T08:01:25-00:00
# 1478  2021-11-22T23:44:03-00:00  2022-05-31T00:50:26-00:00
# 1479  2022-05-05T16:00:01-00:00  2022-05-05T16:00:05-00:00
# 1480  2022-02-03T17:03:08-00:00  2022-05-31T12:11:31-00:00
# 1481  2022-04-21T16:29:49-00:00  2022-04-21T16:29:52-00:00
#
#                                                  handle  \
# 0     ad-icons-general-mills-its-crunch-time-kids-bl...
# 1             star-wars-this-is-the-way-kids-purple-tee
# 2     star-wars-the-mandalorian-this-is-the-way-kids...
# 3        ad-icons-general-mills-midnight-bite-black-tee
# 4           star-wars-where-he-goes-i-go-grogu-kids-tee
# ...                                                 ...
# 1477            marvel-what-if-zombie-hunter-spidey-pop
# 1478                 marvel-what-if-zombie-iron-man-pop
# 1479                      tv-zorro-65th-anniversary-pop
# 1480    anime-avatar-last-airbender-zuko-with-chase-pop
# 1481                           pixar-lightyear-zurg-pop
#
#                                                     img
# 0     https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1     https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 2     https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 3     https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 4     https://cdn.shopify.com/s/files/1/1052/2158/pr...
# ...                                                 ...
# 1477  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1478  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1479  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1480  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1481  https://cdn.shopify.com/s/files/1/1052/2158/pr...
#
# [1482 rows x 18 columns]

# %% [markdown]
# 1. Трябва всички стойности от полето title да се уеднаквят - в момента има такива с кавички, без кавички, трябва да се направят всички на lowercase,

# %%
# 2. Първоначален оглед
print(df.shape)
print(df.info())

# =====================================================
# 3. Премахване на дублирани записи
# =====================================================
df = df.drop_duplicates(subset='uid')

# =====================================================
# 4. Конвертиране на list-ове (в момента са string)
# =====================================================

# функция за безопасно парсване
def safe_literal_eval(val):
    try:
        return ast.literal_eval(val)
    except:
        return []

list_columns = ['interest', 'license', 'tags', 'feature', 'related']

for col in list_columns:
    df[col] = df[col].apply(lambda x: safe_literal_eval(x) if pd.notnull(x) else [])

# =====================================================
# 5. Flatten (правим ги удобни за четене)
# =====================================================

for col in list_columns:
    df[col] = df[col].apply(lambda x: ', '.join(x) if isinstance(x, list) else '')

# =====================================================
# 6. Почистване на HTML от description
# =====================================================

def clean_html(text):
    if pd.isnull(text):
        return ''
    clean = re.sub('<.*?>', '', text)  # маха HTML тагове
    return clean.strip()

# df['description'] = df['description'].apply(clean_html)

# =====================================================
# 7. Конвертиране на дати
# =====================================================

date_cols = ['created_at', 'published_at', 'updated_at']

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

# =====================================================
# 8. Работа с липсващи стойности
# =====================================================

# price → ако има липсващи → махаме редовете (важно поле)
df = df.dropna(subset=['price'])

# vendor → запълваме с "Unknown"
df['vendor'] = df['vendor'].fillna('Unknown')

# =====================================================
# 9. Почистване на текстови полета
# =====================================================

df['title'] = df['title'].str.strip()
df['product_type'] = df['product_type'].str.strip()

# =====================================================
# 10. Feature engineering (много важно за DS)
# =====================================================

# брой тагове
df['tags_count'] = df['tags'].apply(lambda x: len(x.split(',')) if x else 0)

# брой лицензи
df['license_count'] = df['license'].apply(lambda x: len(x.split(',')) if x else 0)

# =====================================================
# 11. Премахване на ненужни колони
# =====================================================

cols_to_drop = ['gid', 'handle', 'img']

df = df.drop(columns=cols_to_drop)

# =====================================================
# 12. Финален изглед
# =====================================================

print(df.head())
print(df.shape)
# Out:
# (1482, 18)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482 entries, 0 to 1481
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   uid           1482 non-null   int64
#  1   title         1482 non-null   object
#  2   product_type  1482 non-null   object
#  3   price         1482 non-null   float64
#  4   interest      1482 non-null   object
#  5   license       1482 non-null   object
#  6   tags          1482 non-null   object
#  7   vendor        1482 non-null   object
#  8   form_factor   1482 non-null   object
#  9   feature       1482 non-null   object
#  10  related       1482 non-null   object
#  11  description   1482 non-null   object
#  12  gid           1482 non-null   object
#  13  created_at    1482 non-null   object
#  14  published_at  1482 non-null   object
#  15  updated_at    1482 non-null   object
#  16  handle        1482 non-null   object
#  17  img           1482 non-null   object
# dtypes: float64(1), int64(1), object(16)
# memory usage: 208.5+ KB
# None
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 43
#      40     clean = re.sub('<.*?>', '', text)  # маха HTML тагове
#      41     return clean.strip()
# ---> 43 df['description'] = df['description'].apply(clean_html)
#      45 # =====================================================
#      46 # 7. Конвертиране на дати
#      47 # =====================================================
#      49 date_cols = ['created_at', 'published_at', 'updated_at']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 40, in clean_html(text)
#      38 if pd.isnull(text):
#      39     return ''
# ---> 40 clean = re.sub('<.*?>', '', text)  # маха HTML тагове
#      41 return clean.strip()
#
# NameError: name 're' is not defined
