# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import ast
import json
import plotly.express as px
from dash import Dash, dcc, html
from scipy.stats import pearsonr
import re

# %%
pd.set_option("display.max_columns", None)

# %%
# Load the dataset
df = pd.read_csv("funko.csv")

# Check shape and first few rows
print(df.shape)
df.head()
# Out:
# (1482, 18)
#              uid                                              title  \
# 0  7051374362813       "It's Crunch Time " Kids Tee - General Mills
# 1  7231381405885       "This is the Way" Kids Tee - The Mandalorian
# 2  7231381536957  "This is the Way" Neon Blast Kids Tee - The Ma...
# 3  7051374395581     "Time for a Midnight Bite" Tee - General Mills
# 4  7231381668029  "Where He Goes, I Go" Grogu Kids Tee - The Man...
#
#   product_type  price       interest            license  \
# 0      Apparel    7.0   ['Ad Icons']  ['General Mills']
# 1      Apparel   10.0  ['Star Wars']      ['Star Wars']
# 2      Apparel   10.0  ['Star Wars']      ['Star Wars']
# 3      Apparel   14.0   ['Ad Icons']  ['General Mills']
# 4      Apparel   10.0  ['Star Wars']      ['Star Wars']
#
#                                                 tags             vendor  \
# 0  ['Apparel', 'Cereal Day', 'Kids Tee', 'Markdow...  Funko Pop Up Shop
# 1  ['Apparel', 'Kids Tee', 'May the 4th', 'May th...         Funko Shop
# 2  ['Apparel', 'May the 4th', 'May the 4th Be Wit...         Funko Shop
# 3  ['Apparel', 'Cereal Day', 'Markdown Item', 'Sa...  Funko Pop Up Shop
# 4  ['Apparel', 'May the 4th', 'May the 4th Be Wit...         Funko Shop
#
#   form_factor feature                                            related  \
# 0          []      []  ['7051374788797', '7051374854333', '7051374723...
# 1          []      []  ['7254814130365', '7254814064829', '4491928240...
# 2          []      []  ['7254814130365', '7254814064829', '4491928240...
# 3          []      []  ['7051374788797', '7051374854333', '7051374723...
# 4          []      []  ['7254814130365', '7254814064829', '4491928240...
#
#                                          description  \
# 0  <p>"It's Crunch Time" with the Count Chocula P...
# 1  <p>Celebrate May the Fourth in stellar style w...
# 2  <p>Celebrate May the Fourth in stellar style w...
# 3  <p>Like the Pop! Tee says, it's "Time for a Mi...
# 4  <p>Celebrate May the Fourth in stellar style w...
#
#                                    gid                 created_at  \
# 0  gid://shopify/Product/7051374362813  2021-10-29T00:02:52-00:00
# 1  gid://shopify/Product/7231381405885  2022-05-03T20:57:34-00:00
# 2  gid://shopify/Product/7231381536957  2022-05-03T20:57:40-00:00
# 3  gid://shopify/Product/7051374395581  2021-10-29T00:02:57-00:00
# 4  gid://shopify/Product/7231381668029  2022-05-03T20:57:45-00:00
#
#                 published_at                 updated_at  \
# 0  2021-10-29T16:30:00-00:00  2022-05-23T16:50:36-00:00
# 1  2022-05-04T15:30:00-00:00  2022-05-27T13:25:49-00:00
# 2  2022-05-04T15:30:01-00:00  2022-05-29T18:15:32-00:00
# 3  2021-10-29T16:30:01-00:00  2022-05-26T04:04:45-00:00
# 4  2022-05-04T15:30:02-00:00  2022-05-30T02:40:26-00:00
#
#                                               handle  \
# 0  ad-icons-general-mills-its-crunch-time-kids-bl...
# 1          star-wars-this-is-the-way-kids-purple-tee
# 2  star-wars-the-mandalorian-this-is-the-way-kids...
# 3     ad-icons-general-mills-midnight-bite-black-tee
# 4        star-wars-where-he-goes-i-go-grogu-kids-tee
#
#                                                  img
# 0  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 1  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 2  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 3  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 4  https://cdn.shopify.com/s/files/1/1052/2158/pr...

# %%
# inspect the column types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1482 entries, 7051374362813 to 7222808182973
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1482 non-null   object
#  1   product_type  1482 non-null   object
#  2   price         1482 non-null   float64
#  3   interest      1482 non-null   object
#  4   license       1482 non-null   object
#  5   tags          1482 non-null   object
#  6   vendor        1482 non-null   object
#  7   related       1482 non-null   object
#  8   description   1482 non-null   object
#  9   gid           1482 non-null   object
#  10  created_at    1482 non-null   datetime64[ns, UTC]
#  11  published_at  1482 non-null   datetime64[ns, UTC]
#  12  updated_at    1482 non-null   datetime64[ns, UTC]
#  13  handle        1482 non-null   object
#  14  img           1482 non-null   object
# dtypes: datetime64[ns, UTC](3), float64(1), object(11)
# memory usage: 185.2+ KB

# %%
# # ---------- CONFIG ----------
MULTI_COLS = ["interest", "license", "tags"]     # columns that have list-like strings
DATE_COLS  = ["created_at", "published_at", "updated_at"]  # adjust to your schema
DROP_COLS  = ["gid", "handle", "img"]            # optional drops if present

# %%
# Remove whitespace from all string cells
for c in df.select_dtypes(include="object").columns:
    df[c] = df[c].astype(str).str.strip()

# %%
# Remove HTML from description

if "description" in df.columns:
    # remove any HTML tags
    df["description"] = df["description"].astype(str).str.replace(r"<.*?>", "", regex=True).str.strip()

# %%
# Convert to datetime and strip the time component
for c in [col for col in DATE_COLS if col in df.columns]:
    # 1. Convert to datetime objects (handling the timezone automatically)
    # 2. Extract only the date part using .dt.date
    df[c] = pd.to_datetime(df[c], errors="coerce").dt.date

# %%
# Inspect form_factor column values
# Check if each entry is a list and has a length greater than 0
is_not_empty = df['form_factor'].apply(lambda x: len(x) > 0 if isinstance(x, list) else False)

# Count the occurrences of True (not empty) and False (empty)
counts = is_not_empty.value_counts()

# Display the results
print(f"Empty arrays: {counts.get(False, 0)}")
print(f"Arrays with elements: {counts.get(True, 0)}")
# Out:
# Empty arrays: 1482
# Arrays with elements: 0

# %%
# All values of this column are empty arrays, so this column is unnecessary, so we can remove it

df.drop(columns=["form_factor"], axis=1, inplace=True)

# %%
df
# Out:
#                                                            title product_type  \
# uid
# 7051374362813       "It's Crunch Time " Kids Tee - General Mills      Apparel
# 7231381405885       "This is the Way" Kids Tee - The Mandalorian      Apparel
# 7231381536957  "This is the Way" Neon Blast Kids Tee - The Ma...      Apparel
# 7051374395581     "Time for a Midnight Bite" Tee - General Mills      Apparel
# 7231381668029  "Where He Goes, I Go" Grogu Kids Tee - The Man...      Apparel
# ...                                                          ...          ...
# 6958000734397                   Zombie Hunter Spidey - What If…?         Pop!
# 6958000963773                        Zombie Iron Man - What If…?         Pop!
# 7232416514237                                              Zorro         Pop!
# 6192471605437                  Zuko - Avatar: The Last Airbender         Pop!
# 7222808182973                                   Zurg - Lightyear         Pop!
#
#                price       interest                        license  \
# uid
# 7051374362813    7.0   ['Ad Icons']              ['General Mills']
# 7231381405885   10.0  ['Star Wars']                  ['Star Wars']
# 7231381536957   10.0  ['Star Wars']                  ['Star Wars']
# 7051374395581   14.0   ['Ad Icons']              ['General Mills']
# 7231381668029   10.0  ['Star Wars']                  ['Star Wars']
# ...              ...            ...                            ...
# 6958000734397   12.0     ['Marvel']      ['Spider-Man', 'What If']
# 6958000963773   12.0     ['Marvel']        ['Iron Man', 'What If']
# 7232416514237   12.0   ['Classics']                      ['Zorro']
# 6192471605437   12.0      ['Anime']  ['Avatar The Last Airbender']
# 7222808182973   12.0      ['Pixar']                  ['Lightyear']
#
#                                                             tags  \
# uid
# 7051374362813  ['Apparel', 'Cereal Day', 'Kids Tee', 'Markdow...
# 7231381405885  ['Apparel', 'Kids Tee', 'May the 4th', 'May th...
# 7231381536957  ['Apparel', 'May the 4th', 'May the 4th Be Wit...
# 7051374395581  ['Apparel', 'Cereal Day', 'Markdown Item', 'Sa...
# 7231381668029  ['Apparel', 'May the 4th', 'May the 4th Be Wit...
# ...                                                          ...
# 6958000734397  ['Disney Plus', 'FFCBDAY', 'Gift Box', 'Gift G...
# 6958000963773  ['Disney Plus', 'FFCBDAY', 'Gift Box', 'Gift G...
# 7232416514237           ['FFCBDAY', 'Gift Box', 'NOTIFY', 'PPP']
# 6192471605437  ['Chase', 'FEB032022', 'FFCBDAY', 'Gift Box', ...
# 7222808182973           ['FFCBDAY', 'Gift Box', 'NOTIFY', 'PPP']
#
#                           vendor  \
# uid
# 7051374362813  Funko Pop Up Shop
# 7231381405885         Funko Shop
# 7231381536957         Funko Shop
# 7051374395581  Funko Pop Up Shop
# 7231381668029         Funko Shop
# ...                          ...
# 6958000734397         Funko Shop
# 6958000963773         Funko Shop
# 7232416514237         Funko Shop
# 6192471605437         Funko Shop
# 7222808182973         Funko Shop
#
#                                                          related  \
# uid
# 7051374362813  ['7051374788797', '7051374854333', '7051374723...
# 7231381405885  ['7254814130365', '7254814064829', '4491928240...
# 7231381536957  ['7254814130365', '7254814064829', '4491928240...
# 7051374395581  ['7051374788797', '7051374854333', '7051374723...
# 7231381668029  ['7254814130365', '7254814064829', '4491928240...
# ...                                                          ...
# 6958000734397  ['6218636001469', '7078124683453', '7193953960...
# 6958000963773  ['6958000734397', '7078124683453', '6924450332...
# 7232416514237  ['6161453613245', '7193953599677', '7239037386...
# 6192471605437  ['6192469999805', '6192471867581', '7087723282...
# 7222808182973  ['7151004811453', '6868728348861', '7239037878...
#
#                                                      description  \
# uid
# 7051374362813  "It's Crunch Time" with the Count Chocula Pop!...
# 7231381405885  Celebrate May the Fourth in stellar style with...
# 7231381536957  Celebrate May the Fourth in stellar style with...
# 7051374395581  Like the Pop! Tee says, it's "Time for a Midni...
# 7231381668029  Celebrate May the Fourth in stellar style with...
# ...                                                          ...
# 6958000734397  In the endless possibilities, venture to wonde...
# 6958000963773  In the endless possibilities, venture to wonde...
# 7232416514237  Celebrate the 65th Anniversary of Zorro, the o...
# 6192471605437  "I must capture the Avatar." Zuko, prince to t...
# 7222808182973  Explore infinite possibilities with our Pop! Z...
#
#                                                gid  created_at published_at  \
# uid
# 7051374362813  gid://shopify/Product/7051374362813  2021-10-29   2021-10-29
# 7231381405885  gid://shopify/Product/7231381405885  2022-05-03   2022-05-04
# 7231381536957  gid://shopify/Product/7231381536957  2022-05-03   2022-05-04
# 7051374395581  gid://shopify/Product/7051374395581  2021-10-29   2021-10-29
# 7231381668029  gid://shopify/Product/7231381668029  2022-05-03   2022-05-04
# ...                                            ...         ...          ...
# 6958000734397  gid://shopify/Product/6958000734397  2021-09-09   2022-05-26
# 6958000963773  gid://shopify/Product/6958000963773  2021-09-09   2021-11-22
# 7232416514237  gid://shopify/Product/7232416514237  2022-05-04   2022-05-05
# 6192471605437  gid://shopify/Product/6192471605437  2021-01-28   2022-02-03
# 7222808182973  gid://shopify/Product/7222808182973  2022-04-20   2022-04-21
#
#                updated_at                                             handle  \
# uid
# 7051374362813  2022-05-23  ad-icons-general-mills-its-crunch-time-kids-bl...
# 7231381405885  2022-05-27          star-wars-this-is-the-way-kids-purple-tee
# 7231381536957  2022-05-29  star-wars-the-mandalorian-this-is-the-way-kids...
# 7051374395581  2022-05-26     ad-icons-general-mills-midnight-bite-black-tee
# 7231381668029  2022-05-30        star-wars-where-he-goes-i-go-grogu-kids-tee
# ...                   ...                                                ...
# 6958000734397  2022-05-31            marvel-what-if-zombie-hunter-spidey-pop
# 6958000963773  2022-05-31                 marvel-what-if-zombie-iron-man-pop
# 7232416514237  2022-05-05                      tv-zorro-65th-anniversary-pop
# 6192471605437  2022-05-31    anime-avatar-last-airbender-zuko-with-chase-pop
# 7222808182973  2022-04-21                           pixar-lightyear-zurg-pop
#
#                                                              img
# uid
# 7051374362813  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7231381405885  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7231381536957  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7051374395581  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7231381668029  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# ...                                                          ...
# 6958000734397  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 6958000963773  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7232416514237  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 6192471605437  https://cdn.shopify.com/s/files/1/1052/2158/pr...
# 7222808182973  https://cdn.shopify.com/s/files/1/1052/2158/pr...
#
# [1482 rows x 15 columns]

# %%
# We should do the same for 'feature' column
# Check if each entry is a list and has a length greater than 0
is_not_empty_feature_column = df['feature'].apply(lambda x: len(x) > 0 if isinstance(x, list) else False)

# Count the occurrences of True (not empty) and False (empty)
counts = is_not_empty_feature_column.value_counts()

# Display the results
print(f"Empty arrays: {counts.get(False, 0)}")
print(f"Arrays with elements: {counts.get(True, 0)}")
# Out:
# Empty arrays: 1482
# Arrays with elements: 0

# %%
# This column is also empty, so we can safely to drop it

df.drop(columns=["feature"], axis=1, inplace=True)

# %%
# Now we need to check if we use the uid column as the primary key column

isColumnUnique = df["uid"].is_unique

isColumnUnique
# Out:
# True

# %%
# After the check above, we can be sure that it is safe to use the id column as the primary key column

df.set_index('uid', inplace=True)

# %%
df
# Out:
#                                                            title product_type  \
# uid
# 7051374362813           Its Crunch Time  Kids Tee  General Mills      Apparel
# 7231381405885          This is the Way Kids Tee  The Mandalorian      Apparel
# 7231381536957  This is the Way Neon Blast Kids Tee  The Manda...      Apparel
# 7051374395581        Time for a Midnight Bite Tee  General Mills      Apparel
# 7231381668029  Where He Goes, I Go Grogu Kids Tee  The Mandal...      Apparel
# ...                                                          ...          ...
# 6958000734397                    Zombie Hunter Spidey  What If…?         Pop!
# 6958000963773                         Zombie Iron Man  What If…?         Pop!
# 7232416514237                                              Zorro         Pop!
# 6192471605437                   Zuko  Avatar: The Last Airbender         Pop!
# 7222808182973                                    Zurg  Lightyear         Pop!
#
#                price     interest                      license  \
# uid
# 7051374362813    7.0   [Ad Icons]              [General Mills]
# 7231381405885   10.0  [Star Wars]                  [Star Wars]
# 7231381536957   10.0  [Star Wars]                  [Star Wars]
# 7051374395581   14.0   [Ad Icons]              [General Mills]
# 7231381668029   10.0  [Star Wars]                  [Star Wars]
# ...              ...          ...                          ...
# 6958000734397   12.0     [Marvel]        [Spider-Man, What If]
# 6958000963773   12.0     [Marvel]          [Iron Man, What If]
# 7232416514237   12.0   [Classics]                      [Zorro]
# 6192471605437   12.0      [Anime]  [Avatar The Last Airbender]
# 7222808182973   12.0      [Pixar]                  [Lightyear]
#
#                                                             tags  \
# uid
# 7051374362813  [Apparel, Cereal Day, Kids Tee, Markdown Item,...
# 7231381405885  [Apparel, Kids Tee, May the 4th, May the 4th B...
# 7231381536957  [Apparel, May the 4th, May the 4th Be With You...
# 7051374395581  [Apparel, Cereal Day, Markdown Item, Sale, T-S...
# 7231381668029  [Apparel, May the 4th, May the 4th Be With You...
# ...                                                          ...
# 6958000734397  [Disney Plus, FFCBDAY, Gift Box, Gift Guide Bi...
# 6958000963773  [Disney Plus, FFCBDAY, Gift Box, Gift Guide Bi...
# 7232416514237                   [FFCBDAY, Gift Box, NOTIFY, PPP]
# 6192471605437  [Chase, FEB032022, FFCBDAY, Gift Box, Gift Gui...
# 7222808182973                   [FFCBDAY, Gift Box, NOTIFY, PPP]
#
#                           vendor  \
# uid
# 7051374362813  Funko Pop Up Shop
# 7231381405885         Funko Shop
# 7231381536957         Funko Shop
# 7051374395581  Funko Pop Up Shop
# 7231381668029         Funko Shop
# ...                          ...
# 6958000734397         Funko Shop
# 6958000963773         Funko Shop
# 7232416514237         Funko Shop
# 6192471605437         Funko Shop
# 7222808182973         Funko Shop
#
#                                                          related  \
# uid
# 7051374362813  ['7051374788797', '7051374854333', '7051374723...
# 7231381405885  ['7254814130365', '7254814064829', '4491928240...
# 7231381536957  ['7254814130365', '7254814064829', '4491928240...
# 7051374395581  ['7051374788797', '7051374854333', '7051374723...
# 7231381668029  ['7254814130365', '7254814064829', '4491928240...
# ...                                                          ...
# 6958000734397  ['6218636001469', '7078124683453', '7193953960...
# 6958000963773  ['6958000734397', '7078124683453', '6924450332...
# 7232416514237  ['6161453613245', '7193953599677', '7239037386...
# 6192471605437  ['6192469999805', '6192471867581', '7087723282...
# 7222808182973  ['7151004811453', '6868728348861', '7239037878...
#
#                                                      description  \
# uid
# 7051374362813  Its Crunch Time with the Count Chocula Pop! Te...
# 7231381405885  Celebrate May the Fourth in stellar style with...
# 7231381536957  Celebrate May the Fourth in stellar style with...
# 7051374395581  Like the Pop! Tee says, its Time for a Midnigh...
# 7231381668029  Celebrate May the Fourth in stellar style with...
# ...                                                          ...
# 6958000734397  In the endless possibilities, venture to wonde...
# 6958000963773  In the endless possibilities, venture to wonde...
# 7232416514237  Celebrate the 65th Anniversary of Zorro, the o...
# 6192471605437  I must capture the Avatar. Zuko, prince to the...
# 7222808182973  Explore infinite possibilities with our Pop! Z...
#
#                                                gid  created_at published_at  \
# uid
# 7051374362813  gid://shopify/Product/7051374362813  2021-10-29   2021-10-29
# 7231381405885  gid://shopify/Product/7231381405885  2022-05-03   2022-05-04
# 7231381536957  gid://shopify/Product/7231381536957  2022-05-03   2022-05-04
# 7051374395581  gid://shopify/Product/7051374395581  2021-10-29   2021-10-29
# 7231381668029  gid://shopify/Product/7231381668029  2022-05-03   2022-05-04
# ...                                            ...         ...          ...
# 6958000734397  gid://shopify/Product/6958000734397  2021-09-09   2022-05-26
# 6958000963773  gid://shopify/Product/6958000963773  2021-09-09   2021-11-22
# 7232416514237  gid://shopify/Product/7232416514237  2022-05-04   2022-05-05
# 6192471605437  gid://shopify/Product/6192471605437  2021-01-28   2022-02-03
# 7222808182973  gid://shopify/Product/7222808182973  2022-04-20   2022-04-21
#
#                updated_at                                             handle  \
# uid
# 7051374362813  2022-05-23  ad-icons-general-mills-its-crunch-time-kids-bl...
# 7231381405885  2022-05-27          star-wars-this-is-the-way-kids-purple-tee
# 7231381536957  2022-05-29  star-wars-the-mandalorian-this-is-the-way-kids...
# 7051374395581  2022-05-26     ad-icons-general-mills-midnight-bite-black-tee
# 7231381668029  2022-05-30        star-wars-where-he-goes-i-go-grogu-kids-tee
# ...                   ...                                                ...
# 6958000734397  2022-05-31            marvel-what-if-zombie-hunter-spidey-pop
# 6958000963773  2022-05-31                 marvel-what-if-zombie-iron-man-pop
# 7232416514237  2022-05-05                      tv-zorro-65th-anniversary-pop
# 6192471605437  2022-05-31    anime-avatar-last-airbender-zuko-with-chase-pop
# 7222808182973  2022-04-21                           pixar-lightyear-zurg-pop
#
#                                                              img  is_chase
# uid
# 7051374362813  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7231381405885  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7231381536957  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7051374395581  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7231381668029  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# ...                                                          ...       ...
# 6958000734397  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 6958000963773  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7232416514237  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 6192471605437  https://cdn.shopify.com/s/files/1/1052/2158/pr...      True
# 7222808182973  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
#
# [1482 rows x 16 columns]

# %%
# 1. Remove double quotes, single quotes and specific special characters
# 2. Strip leading/trailing whitespaces
df['title'] = (
    df['title']
    .str.replace(r'[\"\'\-]', '', regex=True) # Removes ", ' and -
    .str.strip()                             # Removes spaces at the beginning and end
)

# %%
# Do the same for description field

df['description'] = (
    df['description']
    .str.replace(r'[\"\'\-]', '', regex=True) # Removes ", ' and -
    .str.strip()                             # Removes spaces at the beginning and end
)

# %%
# Now we need to cast list comumns to real lists, because now they are strings

def safe_literal_eval(val):
    """
    Safely convert string representation of a list into an actual Python list.
    Handles cases where data might already be a list or is NaN/None.
    """
    if isinstance(val, str) and val.startswith('['):
        try:
            return ast.literal_eval(val)
        except (ValueError, SyntaxError):
            return [] # Return empty list if parsing fails
    elif isinstance(val, list):
        return val
    else:
        return [] # Return empty list for NaN or unexpected types

# Apply the conversion to each column in MULTI_COLS
for col in [c for c in MULTI_COLS if c in df.columns]:
    df[col] = df[col].apply(safe_literal_eval)

# %%
# In the future, I would like to make statisctics about chase figures
# Note: chase fugire is like rear version of normal figure. It's deferent, but when you buy normal figure, there is about 20% chance to receive chase version of the figure instead of the normal version

# Create a new boolean column 'is_chase'
# We iterate through each list in 'tags' and check if 'chase' exists in any form
df['is_chase'] = df['tags'].apply(
    lambda tags_list: any('chase' in str(tag).lower() for tag in tags_list) 
    if isinstance(tags_list, list) else False
)

# %%
# Calculate the percentage of Chase figures
# .mean() on a boolean column gives the ratio of True values (e.g., 0.15 for 15%)
chase_percentage = df['is_chase'].mean() * 100

# Calculate absolute counts for better context
total_count = len(df)
chase_count = df['is_chase'].sum()

print(f"Total items: {total_count}")
print(f"Chase items: {chase_count}")
print(f"Percentage of Chase figures: {chase_percentage:.2f}%")
# Out:
# Total items: 1482
# Chase items: 100
# Percentage of Chase figures: 6.75%

# %%
# Now lets check the top 20 most expensive figures

# 1. Sort by price descending and take the top 20
top_20_expensive = df.sort_values(by='price', ascending=False).head(20)

# 2. Set the visual style
plt.figure(figsize=(12, 10))
sns.set_theme(style="whitegrid")

# 3. Create the barplot
# Assigning y to hue and setting legend=False to fix the FutureWarning
# Using 'is_chase' for hue to visually distinguish Chase items
plot = sns.barplot(
    data=top_20_expensive,
    x='price',
    y='title',
    hue='title',      # Assigning y variable to hue as requested by Seaborn
    palette='viridis',
    legend=False      # Removes the redundant legend
)

# 4. Add labels and title
plt.title('Top 20 Most Expensive Figures', fontsize=16, pad=20)
plt.xlabel('Price ($)', fontsize=12)
plt.ylabel('Product Title', fontsize=12)

# 5. Add price labels at the end of each bar
for i, price in enumerate(top_20_expensive['price']):
    if not pd.isna(price):
        plt.text(price, i, f' ${price:,.2f}', va='center', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()

# %%
top_20_expensive
# Out:
#                                                            title  \
# uid
# 7254814228669  R2D2 Pop! and XWing Mini Backpack Bundle  Star...
# 7248075129021            Masters of the Universe Skateboard Deck
# 7076869701821                      18 Iron Man  Avengers Endgame
# 7254814163133                        Star Wars Celebration 5Pack
# 7254814195901  Lando Calrissian in the Millennium Falcon  Sta...
# 7164050768061    Jurassic Park  Tyrannosaurus Rex & Velociraptor
# 7052530221245                                 Iron Man  Avengers
# 6971383611581                             Batman 1989  DC Comics
# 7107469050045        Wonder Woman with Sword & Shield  DC Comics
# 7231381962941                             Darth Vader  Star Wars
# 6097266245821                                8 Pop! Display Case
# 7250150555837  The Nightmare Before Christmas 13 Day Countdow...
# 7065124372669                               Snapsies Gems  5Pack
# 6956017516733      Grogu This Is the Way Hoodie  The Mandalorian
# 7095630135485            Darth Vader Dark Side Hoodie  Star Wars
# 7117669695677                       Funko Original Script Hoodie
# 4174075461698                   Funkoverse: DC Comics 100  4Pack
# 7239040368829  Ginny Weasley with Flourish & Blotts  Harry Po...
# 4471423991874                Funkoverse: Jurassic Park 100 4Pack
# 4174093058114                 Funkoverse: Harry Potter 100 4Pack
#
#                     product_type  price                           interest  \
# uid
# 7254814228669         Pop! & Bag  105.0                        [Star Wars]
# 7248075129021         Skateboard  100.0     [Cartoon Classics, Retro Toys]
# 7076869701821          Pop! Mega  100.0                           [Marvel]
# 7254814163133               Pop!   70.0                        [Star Wars]
# 7254814195901         Pop! Rides   65.0                        [Star Wars]
# 7164050768061  Pop! Movie Poster   60.0               [Action & Adventure]
# 7052530221245      Pop! Die-Cast   50.0                           [Marvel]
# 6971383611581      Pop! Die-Cast   50.0                        [DC Comics]
# 7107469050045      Pop! Die-Cast   50.0                        [DC Comics]
# 7231381962941      Pop! Die-Cast   50.0                        [Star Wars]
# 6097266245821     Pop! Accessory   50.0                       [Brand Shop]
# 7250150555837    Advent Calendar   50.0                           [Disney]
# 7065124372669           SNAPSIES   45.0                       [Funko Toys]
# 6956017516733            Apparel   45.0       [Star Wars, The Mandalorian]
# 7095630135485            Apparel   45.0                        [Star Wars]
# 7117669695677            Apparel   45.0                       [Brand Shop]
# 4174075461698        Board Games   40.0           [DC Comics, Funko Games]
# 7239040368829        Pop! Deluxe   40.0                     [Harry Potter]
# 4471423991874        Board Games   40.0  [Action & Adventure, Funko Games]
# 4174093058114        Board Games   40.0        [Funko Games, Harry Potter]
#
#                                         license  \
# uid
# 7254814228669                       [Star Wars]
# 7248075129021         [Masters of the Universe]
# 7076869701821      [Avengers Endgame, Iron Man]
# 7254814163133                       [Star Wars]
# 7254814195901                       [Star Wars]
# 7164050768061                   [Jurassic Park]
# 7052530221245              [Avengers, Iron Man]
# 6971383611581                          [Batman]
# 7107469050045                    [Wonder Woman]
# 7231381962941                       [Star Wars]
# 6097266245821                           [Funko]
# 7250150555837  [The Nightmare Before Christmas]
# 7065124372669                        [Snapsies]
# 6956017516733      [Star Wars, The Mandalorian]
# 7095630135485                       [Star Wars]
# 7117669695677                           [Funko]
# 4174075461698                          [Batman]
# 7239040368829                    [Harry Potter]
# 4471423991874                   [Jurassic Park]
# 4174093058114                    [Harry Potter]
#
#                                                             tags  \
# uid
# 7254814228669  [Backpack, Bag, Bundle, Diamond Collection, EX...
# 7248075129021               [EXCLUSIVE, Game Stop, Review Stock]
# 7076869701821  [Black Friday, EXCLUSIVE, Father's Day Gift Gu...
# 7254814163133  [5-Pack, EXCLUSIVE, FSEM, Limit=1, Star Wars C...
# 7254814195901  [Amazon, EXCLUSIVE, FSEM, Limit=1, Star Wars C...
# 7164050768061           [Funko Fair 2022, Jurassic Park, NOTIFY]
# 7052530221245  [Diecast, EXCLUSIVE, Father's Day Gift Guide, ...
# 6971383611581  [Batman Day, DEC272021, Diecast, EXCLUSIVE, Fa...
# 7107469050045              [DEC272021, Diecast, EXCLUSIVE, FSEM]
# 7231381962941  [Chase, Die-Cast, Diecast, EXCLUSIVE, flash, F...
# 6097266245821  [EXCLUSIVE, Gift Guide Splurge, NOV25, Republi...
# 7250150555837  [Advent Calendar, Black Light, Funkoween 2022,...
# 7065124372669  [5-Pack, Easter Promo, Gift Guide Kids Family,...
# 6956017516733  [Apparel, Disney Plus, EXCLUSIVE, FSEM, Gift G...
# 7095630135485        [Apparel, Holiday 2021, Hoodie, Sweatshirt]
# 7117669695677                      [Apparel, Hoodie, Sweatshirt]
# 4174075461698  [Board Games, Funko Family at Home, Funkoverse...
# 7239040368829                     [EXCLUSIVE, MAY112022, Target]
# 4471423991874  [All Products, Base, Board Games, Funko Family...
# 4174093058114  [Board Games, Funko Family at Home, Funkoverse...
#
#                           vendor  \
# uid
# 7254814228669  Funko Pop Up Shop
# 7248075129021      NoEmpDiscount
# 7076869701821      NoEmpDiscount
# 7254814163133  Funko Pop Up Shop
# 7254814195901  Funko Pop Up Shop
# 7164050768061         Funko Shop
# 7052530221245      NoEmpDiscount
# 6971383611581      NoEmpDiscount
# 7107469050045      NoEmpDiscount
# 7231381962941  Funko Pop Up Shop
# 6097266245821  Funko Pop Up Shop
# 7250150555837         Funko Shop
# 7065124372669         Funko Shop
# 6956017516733      NoEmpDiscount
# 7095630135485         Funko Shop
# 7117669695677         Funko Shop
# 4174075461698         Funko Shop
# 7239040368829      NoEmpDiscount
# 4471423991874         Funko Shop
# 4174093058114         Funko Shop
#
#                                                          related  \
# uid
# 7254814228669  ['7254814130365', '7254814064829', '4491928240...
# 7248075129021  ['6953667395773', '6127454060733', '4540283748...
# 7076869701821  ['6924450332861', '7209033007293', '7122096455...
# 7254814163133  ['7254814130365', '7254814064829', '4491928240...
# 7254814195901  ['7254814130365', '7254814064829', '4491928240...
# 7164050768061  ['7248075489469', '7248075587773', '4491927617...
# 7052530221245  ['4491924897858', '4491926667330', '6633589866...
# 6971383611581  ['6971382890685', '4491929616450', '7234788294...
# 7107469050045  ['7122094096573', '6980598530237', '7084657344...
# 7231381962941  ['7254814130365', '7254814064829', '4491928240...
# 6097266245821  ['7087723643069', '6878803525821', '7247422062...
# 7250150555837  ['7122098847933', '7012605100221', '7251689832...
# 7065124372669  ['7224158814397', '7224158748861', '7224158781...
# 6956017516733  ['7254814130365', '7254814064829', '4491928240...
# 7095630135485  ['7254814130365', '7254814064829', '4491928240...
# 7117669695677  ['7087723643069', '6878803525821', '7247422062...
# 4174075461698  ['7181008175293', '6978457403581', '6978455994...
# 7239040368829  ['6213233148093', '4602581680194', '6927194718...
# 4471423991874  ['7248075489469', '7248075587773', '4491927617...
# 4174093058114  ['6213233148093', '4602581680194', '7239040368...
#
#                                                      description  \
# uid
# 7254814228669  Soar through the day with ease with this Funko...
# 7248075129021  Decide the fate of Eterna in your Masters of t...
# 7076869701821  Tony Stark gears up in his red and gold Iron M...
# 7254814163133  Celebrate a faraway galaxy of stellar characte...
# 7254814195901  Celebrate a faraway galaxy of stellar characte...
# 7164050768061  Jurassic Park shook cinemas around the world u...
# 7052530221245  Behold! The new premiere Pop! figure, designed...
# 6971383611581  Introducing the new Pop! Diecast figure, desig...
# 7107469050045  Pop! Diecast is designed to be the front and c...
# 7231381962941  Behold! The new premiere Pop! figure, designed...
# 6097266245821  Protect your prized Pops! with the new 8 Pop! ...
# 7250150555837  Count down to your favorite holiday, or any sp...
# 7065124372669  SNAPSIES™ are back and they’re bringing someth...
# 6956017516733  Capture the moment for your Star Wars™ The Man...
# 7095630135485  Do not resist. Join the dark side, and advocat...
# 7117669695677  Get ready for fun with a Funko Original Script...
# 4174075461698  Go on a heroic adventure with your favorite DC...
# 7239040368829  Students of Hogwarts School of Witchcraft and ...
# 4471423991874  Do you think Ray Arnold and Ellie Sattler make...
# 4174093058114  Accio Funkoverse strategy game! Go on a magica...
#
#                                                gid  created_at published_at  \
# uid
# 7254814228669  gid://shopify/Product/7254814228669  2022-05-26   2022-05-27
# 7248075129021  gid://shopify/Product/7248075129021  2022-05-14   2022-05-16
# 7076869701821  gid://shopify/Product/7076869701821  2021-11-23   2021-11-26
# 7254814163133  gid://shopify/Product/7254814163133  2022-05-26   2022-05-27
# 7254814195901  gid://shopify/Product/7254814195901  2022-05-26   2022-05-27
# 7164050768061  gid://shopify/Product/7164050768061  2022-02-15   2022-02-16
# 7052530221245  gid://shopify/Product/7052530221245  2021-10-29   2021-11-01
# 6971383611581  gid://shopify/Product/6971383611581  2021-09-16   2021-12-27
# 7107469050045  gid://shopify/Product/7107469050045  2021-12-23   2021-12-27
# 7231381962941  gid://shopify/Product/7231381962941  2022-05-03   2022-05-05
# 6097266245821  gid://shopify/Product/6097266245821  2020-11-25   2021-07-19
# 7250150555837  gid://shopify/Product/7250150555837  2022-05-17   2022-05-18
# 7065124372669  gid://shopify/Product/7065124372669  2021-11-09   2021-11-10
# 6956017516733  gid://shopify/Product/6956017516733  2021-09-08   2021-09-09
# 7095630135485  gid://shopify/Product/7095630135485  2021-12-09   2021-12-10
# 7117669695677  gid://shopify/Product/7117669695677  2022-01-06   2022-01-07
# 4174075461698  gid://shopify/Product/4174075461698  2019-10-01   2019-10-01
# 7239040368829  gid://shopify/Product/7239040368829  2022-05-10   2022-05-11
# 4471423991874  gid://shopify/Product/4471423991874  2020-03-02   2020-03-02
# 4174093058114  gid://shopify/Product/4174093058114  2019-10-01   2019-10-01
#
#                updated_at                                             handle  \
# uid
# 7254814228669  2022-05-29  star-wars-celebration-r2-d2-pop-and-x-wing-min...
# 7248075129021  2022-05-30             master-of-the-universe-skateboard-deck
# 7076869701821  2022-05-31  marvel-avengers-endgame-18-inch-iron-man-pop-mega
# 7254814163133  2022-05-30                   star-wars-celebration-5-pack-pop
# 7254814195901  2022-05-29  star-wars-celebration-lando-calrissian-millenn...
# 7164050768061  2022-05-18  jurassic-park-tyrannosaurus-rex-velociraptor-p...
# 7052530221245  2022-05-31              marvel-avengers-iron-man-pop-die-cast
# 6971383611581  2022-05-31                 dc-comics-batman-1989-pop-die-cast
# 7107469050045  2022-05-31   dc-comics-wonder-woman-sword-shield-pop-die-cast
# 7231381962941  2022-05-29                 star-wars-darth-vader-pop-die-cast
# 6097266245821  2022-05-31                brand-shop-8-piece-pop-display-case
# 7250150555837  2022-05-18        disney-tnbc-13-day-countown-advent-calendar
# 7065124372669  2022-05-27                               snapsies-gems-5-pack
# 6956017516733  2022-05-27            star-wars-mandalorian-grogu-navy-hoodie
# 7095630135485  2022-05-29       star-wars-darth-vader-dark-side-black-hoodie
# 7117669695677  2022-05-26                       funko-original-script-hoodie
# 4174075461698  2022-05-27             funkoverse-strategy-game-dc-100-4-pack
# 7239040368829  2022-05-31  harry-potter-ginny-weasley-flourish-and-blotts...
# 4471423991874  2022-05-23  funkoverse-strategy-game-jurassic-park-100-4-pack
# 4174093058114  2022-05-27   funkoverse-strategy-game-harry-potter-100-4-pack
#
#                                                              img  is_chase
# uid
# 7254814228669  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7248075129021  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7076869701821  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7254814163133  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7254814195901  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7164050768061  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7052530221245  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 6971383611581  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7107469050045  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7231381962941  https://cdn.shopify.com/s/files/1/1052/2158/pr...      True
# 6097266245821  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7250150555837  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7065124372669  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 6956017516733  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7095630135485  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7117669695677  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 4174075461698  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 7239040368829  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 4471423991874  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
# 4174093058114  https://cdn.shopify.com/s/files/1/1052/2158/pr...     False
